# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import  seaborn as sb
import warnings 
warnings.filterwarnings ('ignore')

# %%
df=pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %% [markdown]
# ###   Task 1 : Display first 50 rows of Genre and title

# %%
df[['genres','original_title']].head(51)
# Out:
#                                                genres  \
# 0   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# ...

# %% [markdown]
# ### TAsk 2 :-  Identity Null Values and perform Null value Treatment

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# ### Deleting the column homepage  as it has  more NAN values than the actual data

# %%
df.drop('homepage',axis=1,inplace=True)

# %% [markdown]
#  ### Changing the NAN Values with the Mode values

# %%
df['tagline'].mode()
# Out:
# 0    Based on a true story.
# Name: tagline, dtype: object

# %%
df['tagline'].fillna(df['tagline'].mode()[0],inplace=True)

# %%
df['overview'].fillna(df['overview'].mode()[0],inplace=True)

# %% [markdown]
# ### Changing the  NAN values with the mean values

# %%
df['runtime'].fillna(df['runtime'].mean(),inplace=True)

# %% [markdown]
# ### Analysis on the data

# %% [markdown]
# ### Task 3 :- display  movie category where budget is greater than 220000

# %%
 df1= df[df['budget']>220000]

# %%
df1.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %% [markdown]
# ### Task 4 :-  Display  movie Categories where revenue  greater than 961000000

# %%
 df2= df[df['revenue']>961000000]

# %%
df2
# Out:
#         budget                                             genres      id  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   99861
# 12   200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...      58
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...   24428
# 17   380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...    1865
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...     597
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...  271110
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  135397
# 29   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   37724
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   68721
# 32   200000000  [{"id": 10751, "name": "Family"}, {"id": 14, "...   12155
# ...

# %% [markdown]
# ###  Task 5 :- deleting  rows where revenue, budget columns have 0 values

# %%
df=df[(df['revenue']!=0) & (df['budget']!=0) ]

# %%
df
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]    2292
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...     692
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...   36095
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...   14337
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
#
# ...

# %% [markdown]
# ### Task 6 :-  Display  top 10 movies with Highest revenue and TOP 10 movies with highest budget

# %%
df.sort_values(['revenue'], ascending= False).head(10)
# Out:
#         budget                                             genres      id  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...     597
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...   24428
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  135397
# 44   190000000                     [{"id": 28, "name": "Action"}]  168259
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   99861
# 124  150000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...  109445
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   68721
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...  211672
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...  271110
#
#                                               keywords original_language  \
# 0    [{"id": 1463, "name": "culture clash"}, {"id":...                en
# ...

# %%
df.sort_values(['budget'], ascending= True).head(10)
# Out:
#       budget                                             genres      id  \
# 4238       1  [{"id": 18, "name": "Drama"}, {"id": 35, "name...    3082
# 3611       4  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...   22649
# 3372       7  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...   13006
# 3419       7  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...   38415
# 4608       8  [{"id": 14, "name": "Fantasy"}, {"id": 27, "na...   11980
# 3131      10  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...  217708
# 3137      10  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...   78383
# 2933      11  [{"id": 18, "name": "Drama"}, {"id": 28, "name...   28932
# 1912      25                      [{"id": 18, "name": "Drama"}]   10397
# 1771      28  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...    1613
#
#                                                keywords original_language  \
# 4238  [{"id": 1382, "name": "factory"}, {"id": 1546,...                en
# ...

# %% [markdown]
# ###  Task 7 :- How popularity of movies effect the Budget  are they are correlated

# %%
 df3=df.corr()

# %%
df3
# Out:
#                 budget        id  popularity   revenue   runtime  \
# budget        1.000000  0.013624    0.431990  0.705399  0.229490
# id            0.013624  1.000000    0.177854  0.030112 -0.033430
# popularity    0.431990  0.177854    1.000000  0.602246  0.182198
# revenue       0.705399  0.030112    0.602246  1.000000  0.233074
# runtime       0.229490 -0.033430    0.182198  0.233074  1.000000
# vote_average -0.031208 -0.067064    0.286994  0.187839  0.378641
# vote_count    0.540165  0.106880    0.749088  0.756210  0.257922
#
#               vote_average  vote_count
# budget           -0.031208    0.540165
# id               -0.067064    0.106880
# popularity        0.286994    0.749088
# revenue           0.187839    0.756210
# runtime           0.378641    0.257922
# vote_average      1.000000    0.377658
# vote_count        0.377658    1.000000

# %%
# Interpretation :-  Budget and populairty of movies has  positive weak correlation  
# Yes popularity increases budget might aslo increases but  its unriable

# %% [markdown]
# ### Task 8 :-  Display the names of all the production comapnies hand how many times they appear

# %%
df['production_co']=df['production_companies'].apply(lambda x: x.split(',')[0].split(':')[-1])

# %%
df
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]    2292
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...     692
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...   36095
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...   14337
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
#
# ...

# %%
 group=df.groupby('production_co').size()

# %%
group.sort_values(ascending=False)
# Out:
# production_co
#  "Paramount Pictures"                        241
#  "Universal Pictures"                        228
#  "Columbia Pictures"                         166
#  "Twentieth Century Fox Film Corporation"    159
#  "New Line Cinema"                           135
#                                             ...
#  "Lonely Film Productions GmbH & Co. KG."      1
#  "Loew's Incorporated"                         1
#  "Code Entertainment"                          1
#  "Columbia Pictures Industries"                1
#  "Original Pictures"                           1
# Length: 754, dtype: int64

# %% [markdown]
# ### Task 9:-   Display top 25 production companies with there total movie they have produced in descending order

# %%
group.sort_values(ascending=False).head(25)
# Out:
# production_co
#  "Paramount Pictures"                        241
#  "Universal Pictures"                        228
#  "Columbia Pictures"                         166
#  "Twentieth Century Fox Film Corporation"    159
#  "New Line Cinema"                           135
#  "Walt Disney Pictures"                       96
#  "Village Roadshow Pictures"                  64
#  "United Artists"                             61
#  "Miramax Films"                              61
#  "Columbia Pictures Corporation"              58
#  "DreamWorks SKG"                             54
#  "Warner Bros."                               54
#  "Fox Searchlight Pictures"                   46
# []                                            41
#  "Summit Entertainment"                       40
#  "TriStar Pictures"                           36
#  "Metro-Goldwyn-Mayer (MGM)"                  33
#  "Lionsgate"                                  27
#  "The Weinstein Company"                      27
# ...

# %% [markdown]
# ### Task 10 :- Sorting the data based on revenue column and display top 500 movies  And   display measure of central tendency  for budget, revenue, runtime

# %%
 df4=df.sort_values(['revenue'], ascending= False).head(500)

# %%
df4
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...     597
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...   24428
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  135397
# 44    190000000                     [{"id": 28, "name": "Action"}]  168259
# ...         ...                                                ...     ...
# 397    85000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   22897
# 1744   30000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...    4964
# 698    70000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...    9837
# 717    60000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...   75780
# 714    65000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...    1538
#
# ...

# %%
df['budget'].mean()
# Out:
# 40654444.774233505

# %%
df['budget'].median()
# Out:
# 25000000.0

# %%
df['revenue'].mean()
# Out:
# 121242957.26138124

# %%
df['revenue'].median()
# Out:
# 55184721.0

# %%
df['runtime'].mean()
# Out:
# 110.72437287085785

# %%
df['runtime'].median()
# Out:
# 107.0

# %%
df['revenue'].plot(kind='box')
plt.show()

# %%
df['budget'].plot(kind='box')
plt.show()

# %%
df['runtime'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### Task 11:- Dsiplay the movies and run time where the run time is greater than the average run time

# %%
 avg_time=df[df['runtime']>110]

# %%
avg_time[['original_title','runtime']]
# Out:
#                                 original_title  runtime
# 0                                       Avatar    162.0
# 1     Pirates of the Caribbean: At World's End    169.0
# 2                                      Spectre    148.0
# 3                        The Dark Knight Rises    165.0
# 4                                  John Carter    132.0
# ...                                        ...      ...
# 4631                               Chasing Amy    113.0
# 4661                            The Big Parade    151.0
# 4720                     The Birth of a Nation    120.0
# 4722                         Facing the Giants    111.0
# 4792                                       キュア    111.0
#
# [1362 rows x 2 columns]

# %%
 total_movies= len(avg_time)
print('Total movies which have run time greater than the avg run times {}'.format(total_movies))
# Out:
# Total movies which have run time greater than the avg run times 1362
